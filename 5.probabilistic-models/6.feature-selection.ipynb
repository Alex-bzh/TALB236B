# %% [markdown]
# # La sélection de traits

# %% [markdown]
# On vient d'apprendre à classifier, comment sélectionner traits discriminants

# %% [markdown]
# ## Le problème de la haute dimensionnalité

# %% [markdown]
# ## Le gain d’information comme critère de sélection

# %% [markdown]
# ## Autres critères de sélection

# %% [markdown]
# ### Fréquence minimale

# %% [markdown]
# ### Chi deux
